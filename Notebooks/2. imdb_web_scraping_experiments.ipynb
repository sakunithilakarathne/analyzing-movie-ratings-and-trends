# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
all_movie_data=[]
def scrape_imdb_films():
    # Define the page to scrape
    url = "https://www.imdb.com/search/title/?explore=genres&title_type=feature&num_votes=100000,&sort=user_rating,desc"

    # Set headers to avoid blocking
    headers = {"User-Agent": "Mozilla/5.0"}

    # Fetch the page content
    pageToScrape = requests.get(url, headers=headers)
    soup = BeautifulSoup(pageToScrape.text, "html.parser")

    # Find all <td> elements with the class "a-text-left mojo-field-type-title"
    movie_details = soup.findAll('div',class_="sc-d5ea4b9d-0 ejavrk")

    for each in movie_details:
         print(each)

# Call the function
scrape_imdb_films()
# Out:
# <div class="sc-d5ea4b9d-0 ejavrk"><div class="ipc-title ipc-title--base ipc-title--title ipc-title-link-no-icon ipc-title--on-textPrimary sc-3713cfda-2 fSzZES dli-title with-margin"><a class="ipc-title-link-wrapper" href="/title/tt0111161/?ref_=sr_t_1" tabindex="0"><h3 class="ipc-title__text">1. The Shawshank Redemption</h3></a></div><div class="sc-d5ea4b9d-6 hBxwRe dli-title-metadata"><span class="sc-d5ea4b9d-7 URyjV dli-title-metadata-item">1994</span><span class="sc-d5ea4b9d-7 URyjV dli-title-metadata-item">2h 22m</span><span class="sc-d5ea4b9d-7 URyjV dli-title-metadata-item">R</span></div><span class="sc-d5ea4b9d-1 cVWRWO"><div class="sc-e2dbc1a3-0 jeHPdh sc-d5ea4b9d-3 eunRcy dli-ratings-container" data-testid="ratingGroup--container"><span aria-label="IMDb rating: 9.3" class="ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb ratingGroup--imdb-rating" data-testid="ratingGroup--imdb-rating"><svg class="ipc-icon ipc-icon--star-inline" fill="currentColor" height="24" role
# ...

# %%
all_movie_data=[]
def scrape_imdb_films():
    # Define the page to scrape
    url = "https://www.imdb.com/search/title/?explore=genres&title_type=feature&num_votes=100000,&sort=user_rating,desc"

    # Set headers to avoid blocking
    headers = {"User-Agent": "Mozilla/5.0"}

    # Fetch the page content
    pageToScrape = requests.get(url, headers=headers)
    soup = BeautifulSoup(pageToScrape.text, "html.parser")

    # Find all <td> elements with the class "a-text-left mojo-field-type-title"
    movie_details = soup.findAll('div',class_="sc-d5ea4b9d-0 ejavrk")

    for each in movie_details:
         print(each.text)

# Call the function
scrape_imdb_films()
# Out:
# 1. The Shawshank Redemption19942h 22mR9.3 (3M)Rate82Metascore
# 2. The Godfather19722h 55mR9.2 (2.1M)Rate100Metascore
# 3. 12 Angry Men19571h 36mApproved9.0 (911K)Rate97Metascore
# 4. The Dark Knight20082h 32mPG-139.0 (3M)Rate84Metascore
# 5. Schindler's List19933h 15mR9.0 (1.5M)Rate95Metascore
# 6. The Lord of the Rings: The Return of the King20033h 21mPG-139.0 (2.1M)Rate94Metascore
# 7. The Godfather Part II19743h 22mR9.0 (1.4M)Rate90Metascore
# 8. Pulp Fiction19942h 34mR8.9 (2.3M)Rate95Metascore
# 9. The Lord of the Rings: The Fellowship of the Ring20012h 58mPG-138.9 (2.1M)Rate92Metascore
# 10. Inception20102h 28mPG-138.8 (2.7M)Rate74Metascore
# 11. Fight Club19992h 19mR8.8 (2.4M)Rate67Metascore
# 12. Forrest Gump19942h 22mPG-138.8 (2.4M)Rate82Metascore
# 13. Il buono, il brutto, il cattivo19662h 41mR8.8 (843K)Rate90Metascore
# 14. The Lord of the Rings: The Two Towers20022h 59mPG-138.8 (1.9M)Rate87Metascore
# 15. 12th Fail20232h 27m8.8 (142K)Rate
# ...

# %%
# Below function collects the highest rated movies in all genres from IMDB website

# %%
def get_imdb_highest_rated_movies():
    # Base URL for IMDb search
    base_url = "https://www.imdb.com/search/title/"
    genre_list = ["action","adventure","animation","biography","comedy","crime","family","fantasy","history","horror","music","musical","mystery","romance","sport","thriller","war","western"]
    #["action","adventure","animation","biography","comedy","crime","family","fantasy","history","horror","music","musical","mystery","romance","sport","thriller","war","western"]
           
    # List to store all movie titles
    all_movie_data = []
    
    for each_genre in genre_list:
        params = {
            "genres": each_genre,
            "explore": "genres",
            "title_type": "feature",
            "num_votes": "100000,",
            "sort": "user_rating,desc"
        }

        # Set headers to avoid blocking
        headers = {"User-Agent": "Mozilla/5.0"}
        
        # Fetch the page content
        response = requests.get(base_url, params=params, headers=headers)
        soup = BeautifulSoup(response.text, "html.parser")

        # Find all movie titles
        movie_details = soup.findAll('div',class_="sc-d5ea4b9d-0 ejavrk")  # Updated class name

        # Extract and store movie titles
        for movie in movie_details:
            movie_title = movie.find('h3',class_="ipc-title__text").text.split(".")[1]
            movie_id = movie.find('a', class_='ipc-title-link-wrapper').get('href').split('/')[2]
            
            all_movie_data.append({
                "Title": movie_title,
                "IMDb ID": movie_id
            })

    df = pd.DataFrame(data=all_movie_data)
    df_cleaned = df.drop_duplicates(subset=["IMDb ID"]).reset_index(drop=True)
    #display(df)
    return df_cleaned

# Call the function
get_imdb_highest_rated_movies()
# Out:
#                                                  Title    IMDb ID
# 0                                      The Dark Knight  tt0468569
# 1                                            Inception  tt1375666
# 2                                           The Matrix  tt0133093
# 3       Star Wars: Episode V - The Empire Strikes Back  tt0080684
# 4                                            Star Wars  tt0076759
# ..                                                 ...        ...
# 274                                          True Grit  tt1403865
# 275                                       3:10 to Yuma  tt0381849
# 276                                Legends of the Fall  tt0110322
# 277                        Back to the Future Part III  tt0099088
# 278   The Assassination of Jesse James by the Cowar...  tt0443680
#
# [279 rows x 2 columns]

# %%
# Below function collects the most rated movies in all genres from IMDB website

# %%
def get_imdb_most_rated_movies():
    # Base URL for IMDb search
    base_url = "https://www.imdb.com/search/title/"
    genre_list = ["action","adventure","animation","biography","comedy","crime","family","fantasy","history","horror","music","musical","mystery","romance","sport","thriller","war","western"]
    #["action","adventure","animation","biography","comedy","crime","family","fantasy","history","horror","music","musical","mystery","romance","sport","thriller","war","western"]
           
    # List to store all movie titles
    all_movie_data = []
    
    for each_genre in genre_list:
        params = {
            "genres": each_genre,
            "explore": "genres",
            "title_type": "feature",
            "num_votes": "100000,",
            "sort": "num_votes,desc"
        }

        # Set headers to avoid blocking
        headers = {"User-Agent": "Mozilla/5.0"}
        
        # Fetch the page content
        response = requests.get(base_url, params=params, headers=headers)
        soup = BeautifulSoup(response.text, "html.parser")

        # Find all movie titles
        movie_details = soup.findAll('div',class_="sc-d5ea4b9d-0 ejavrk")  # Updated class name

        # Extract and store movie titles
        for movie in movie_details:
            movie_title = movie.find('h3',class_="ipc-title__text").text.split(".")[1]
            movie_id = movie.find('a', class_='ipc-title-link-wrapper').get('href').split('/')[2]
            
            all_movie_data.append({
                "Title": movie_title,
                "IMDb ID": movie_id
            })

    df = pd.DataFrame(data=all_movie_data)
    df_cleaned = df.drop_duplicates(subset=["IMDb ID"]).reset_index(drop=True)
    #display(df)
    return df_cleaned

# Call the function
get_imdb_most_rated_movies()
# Out:
#                                                  Title     IMDb ID
# 0                                      The Dark Knight   tt0468569
# 1                                            Inception   tt1375666
# 2                                           The Matrix   tt0133093
# 3                                The Dark Knight Rises   tt1345836
# 4                                            Gladiator   tt0172495
# ..                                                 ...         ...
# 296                  A Million Ways to Die in the West   tt2557490
# 297                                  The Mask of Zorro   tt0120746
# 298                                          Desperado   tt0112851
# 299                               The Power of the Dog  tt10293406
# 300   The Assassination of Jesse James by the Cowar...   tt0443680
#
# [301 rows x 2 columns]

# %%
# Below function collects the most popular movies in all genres from IMDB website

# %%
def get_imdb_most_popular_movies():
    # Base URL for IMDb search
    base_url = "https://www.imdb.com/search/title/"
    genre_list = ["action","adventure","animation","biography","comedy","crime","family","fantasy","history","horror","music","musical","mystery","romance","sport","thriller","war","western"]
    #["action","adventure","animation","biography","comedy","crime","family","fantasy","history","horror","music","musical","mystery","romance","sport","thriller","war","western"]
           
    # List to store all movie titles
    all_movie_data = []
    
    for each_genre in genre_list:
        params = {
            "genres": each_genre,
            "explore": "genres",
            "title_type": "feature",
            "num_votes": "100000,",
            "sort": "moviemeter,desc"
        }

        # Set headers to avoid blocking
        headers = {"User-Agent": "Mozilla/5.0"}
        
        # Fetch the page content
        response = requests.get(base_url, params=params, headers=headers)
        soup = BeautifulSoup(response.text, "html.parser")

        # Find all movie titles
        movie_details = soup.findAll('div',class_="sc-d5ea4b9d-0 ejavrk")  # Updated class name

        # Extract and store movie titles
        for movie in movie_details:
            movie_title = movie.find('h3',class_="ipc-title__text").text.split(".")[1]
            movie_id = movie.find('a', class_='ipc-title-link-wrapper').get('href').split('/')[2]
            
            all_movie_data.append({
                "Title": movie_title,
                "IMDb ID": movie_id
            })

    df = pd.DataFrame(data=all_movie_data)
    df_cleaned = df.drop_duplicates(subset=["IMDb ID"]).reset_index(drop=True)
    #display(df)
    return df_cleaned

# Call the function
get_imdb_most_popular_movies()
# Out:
#                                    Title     IMDb ID
# 0                                  Radhe  tt10888594
# 1                              Adipurush  tt12915716
# 2             Brahmastra Part One: Shiva   tt6277462
# 3                                Kantara  tt15327088
# 4                                 Dag II   tt5813916
# ..                                   ...         ...
# 266                       The Highwaymen   tt1860242
# 267                            Desperado   tt0112851
# 268               The Quick and the Dead   tt0114214
# 269                 The Power of the Dog  tt10293406
# 270   Butch Cassidy and the Sundance Kid   tt0064115
#
# [271 rows x 2 columns]

# %%
# Below function collects the movies with highest runtime in all genres from IMDB website

# %%
def get_imdb_highest_runtime_movies():
    # Base URL for IMDb search
    base_url = "https://www.imdb.com/search/title/"
    genre_list = ["action","adventure","animation","biography","comedy","crime","family","fantasy","history","horror","music","musical","mystery","romance","sport","thriller","war","western"]
    #["action","adventure","animation","biography","comedy","crime","family","fantasy","history","horror","music","musical","mystery","romance","sport","thriller","war","western"]
           
    # List to store all movie titles
    all_movie_data = []
    
    for each_genre in genre_list:
        params = {
            "genres": each_genre,
            "explore": "genres",
            "title_type": "feature",
            "num_votes": "100000,",
            "sort": "runtime,desc"
        }

        # Set headers to avoid blocking
        headers = {"User-Agent": "Mozilla/5.0"}
        
        # Fetch the page content
        response = requests.get(base_url, params=params, headers=headers)
        soup = BeautifulSoup(response.text, "html.parser")

        # Find all movie titles
        movie_details = soup.findAll('div',class_="sc-d5ea4b9d-0 ejavrk")  # Updated class name

        # Extract and store movie titles
        for movie in movie_details:
            movie_title = movie.find('h3',class_="ipc-title__text").text.split(".")[1]
            movie_id = movie.find('a', class_='ipc-title-link-wrapper').get('href').split('/')[2]
            
            all_movie_data.append({
                "Title": movie_title,
                "IMDb ID": movie_id
            })

    df = pd.DataFrame(data=all_movie_data)
    df_cleaned = df.drop_duplicates(subset=["IMDb ID"]).reset_index(drop=True)
    #display(df)
    return df_cleaned

# Call the function
get_imdb_highest_runtime_movies()
# Out:
#                                  Title     IMDb ID
# 0                   Gangs of Wasseypur   tt1954470
# 1         Zack Snyder's Justice League  tt12361974
# 2                 Shichinin no samurai   tt0047478
# 3                               Animal  tt13751694
# 4             Avatar: The Way of Water   tt1630029
# ..                                 ...         ...
# 282                The Legend of Zorro   tt0386140
# 283              The Magnificent Seven   tt0054047
# 284                           Maverick   tt0110478
# 285               The Power of the Dog  tt10293406
# 286   The Treasure of the Sierra Madre   tt0040897
#
# [287 rows x 2 columns]

# %%
# Below function collects the latest release movies in all genres from IMDB website

# %%
def get_imdb_latest_released_movies():
    # Base URL for IMDb search
    base_url = "https://www.imdb.com/search/title/"
    genre_list = ["action","adventure","animation","biography","comedy","crime","family","fantasy","history","horror","music","musical","mystery","romance","sport","thriller","war","western"]
    #["action","adventure","animation","biography","comedy","crime","family","fantasy","history","horror","music","musical","mystery","romance","sport","thriller","war","western"]
           
    # List to store all movie titles
    all_movie_data = []
    
    for each_genre in genre_list:
        params = {
            "genres": each_genre,
            "explore": "genres",
            "title_type": "feature",
            "num_votes": "100000,",
            "sort": "year,desc"
        }

        # Set headers to avoid blocking
        headers = {"User-Agent": "Mozilla/5.0"}
        
        # Fetch the page content
        response = requests.get(base_url, params=params, headers=headers)
        soup = BeautifulSoup(response.text, "html.parser")

        # Find all movie titles
        movie_details = soup.findAll('div',class_="sc-d5ea4b9d-0 ejavrk")  # Updated class name

        # Extract and store movie titles
        for movie in movie_details:
            movie_title = movie.find('h3',class_="ipc-title__text").text.split(".")[1]
            movie_id = movie.find('a', class_='ipc-title-link-wrapper').get('href').split('/')[2]
            
            all_movie_data.append({
                "Title": movie_title,
                "IMDb ID": movie_id
            })

    df = pd.DataFrame(data=all_movie_data)
    df_cleaned = df.drop_duplicates(subset=["IMDb ID"]).reset_index(drop=True)
    #display(df)
    return df_cleaned

# Call the function
get_imdb_latest_released_movies()
# Out:
#                                                  Title     IMDb ID
# 0                                         Gladiator II   tt9218128
# 1                              Furiosa: A Mad Max Saga  tt12037194
# 2                                       Dune: Part Two  tt15239678
# 3                                 Deadpool & Wolverine   tt6263850
# 4                                            Civil War  tt17279496
# ..                                                 ...         ...
# 255                                       3:10 to Yuma   tt0381849
# 256   The Assassination of Jesse James by the Cowar...   tt0443680
# 257                                The Devil's Rejects   tt0395584
# 258                                The Legend of Zorro   tt0386140
# 259                                      Shanghai Noon   tt0184894
#
# [260 rows x 2 columns]

# %%
# Below function collects the movies with lowest runtime in all genres from IMDB website

# %%
def get_imdb_lowest_runtime_movies():
    # Base URL for IMDb search
    base_url = "https://www.imdb.com/search/title/"
    genre_list = ["action","adventure","animation","biography","comedy","crime","family","fantasy","history","horror","music","musical","mystery","romance","sport","thriller","war","western"]
    #["action","adventure","animation","biography","comedy","crime","family","fantasy","history","horror","music","musical","mystery","romance","sport","thriller","war","western"]
           
    # List to store all movie titles
    all_movie_data = []
    
    for each_genre in genre_list:
        params = {
            "genres": each_genre,
            "explore": "genres",
            "title_type": "feature",
            "num_votes": "100000,",
            "sort": "runtime,asc"
        }

        # Set headers to avoid blocking
        headers = {"User-Agent": "Mozilla/5.0"}
        
        # Fetch the page content
        response = requests.get(base_url, params=params, headers=headers)
        soup = BeautifulSoup(response.text, "html.parser")

        # Find all movie titles
        movie_details = soup.findAll('div',class_="sc-d5ea4b9d-0 ejavrk")  # Updated class name

        # Extract and store movie titles
        for movie in movie_details:
            movie_title = movie.find('h3',class_="ipc-title__text").text.split(".")[1]
            movie_id = movie.find('a', class_='ipc-title-link-wrapper').get('href').split('/')[2]
            
            all_movie_data.append({
                "Title": movie_title,
                "IMDb ID": movie_id
            })

    df = pd.DataFrame(data=all_movie_data)
    df_cleaned = df.drop_duplicates(subset=["IMDb ID"]).reset_index(drop=True)
    #display(df)
    return df_cleaned

# Call the function
get_imdb_lowest_runtime_movies()
# Out:
#                                  Title     IMDb ID
# 0                          The General   tt0017925
# 1                                    9   tt0472033
# 2                           Lola rennt   tt0130827
# 3                       Kôkaku Kidôtai   tt0113568
# 4                              Grimsby   tt3381008
# ..                                 ...         ...
# 263                           Dead Man   tt0112817
# 264                       3:10 to Yuma   tt0381849
# 265               The Power of the Dog  tt10293406
# 266   The Treasure of the Sierra Madre   tt0040897
# 267                           Maverick   tt0110478
#
# [268 rows x 2 columns]

# %%
# Creating a common function to collect data with sorting requirement as a parameter

# %%
def get_imdb__movies(sort_parameter):
    # Base URL for IMDb search
    base_url = "https://www.imdb.com/search/title/"
    genre_list = ["action","adventure","animation","biography","comedy","crime","family","fantasy","history","horror","music","musical","mystery","romance","sport","thriller","war","western"]
    #["action","adventure","animation","biography","comedy","crime","family","fantasy","history","horror","music","musical","mystery","romance","sport","thriller","war","western"]
           
    # List to store all movie titles
    all_movie_data = []
    
    for each_genre in genre_list:
        params = {
            "genres": each_genre,
            "explore": "genres",
            "title_type": "feature",
            "num_votes": "100000,",
            "sort": sort_parameter
        }

        # Set headers to avoid blocking
        headers = {"User-Agent": "Mozilla/5.0"}
        
        # Fetch the page content
        response = requests.get(base_url, params=params, headers=headers)
        soup = BeautifulSoup(response.text, "html.parser")

        # Find all movie titles
        movie_details = soup.findAll('div',class_="sc-d5ea4b9d-0 ejavrk")  # Updated class name

        # Extract and store movie titles
        for movie in movie_details:
            movie_title = movie.find('h3',class_="ipc-title__text").text.split(".")[1]
            movie_id = movie.find('a', class_='ipc-title-link-wrapper').get('href').split('/')[2]
            
            all_movie_data.append({
                "Title": movie_title,
                "IMDb ID": movie_id
            })

    df = pd.DataFrame(data=all_movie_data)
    df_cleaned = df.drop_duplicates(subset=["IMDb ID"]).reset_index(drop=True)
    #display(df)
    return df_cleaned

# Call the function to collect least rated movies
get_imdb__movies("num_votes,asc")
# Out:
#                                                  Title     IMDb ID
# 0                                  Season of the Witch   tt0479997
# 1                                        Project Power   tt7550000
# 2                                     Edge of Darkness   tt1226273
# 3                                              Elektra   tt0357277
# 4                                                 Anna   tt7456310
# ..                                                 ...         ...
# 253                                Legends of the Fall   tt0110322
# 254                           The Last of the Mohicans   tt0104691
# 255   The Assassination of Jesse James by the Cowar...   tt0443680
# 256                               The Power of the Dog  tt10293406
# 257                                          Desperado   tt0112851
#
# [258 rows x 2 columns]
